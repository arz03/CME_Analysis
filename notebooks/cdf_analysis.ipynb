# %%
# imports
import cdflib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import datetime, timezone

# %% [markdown]
# # File Analysis

# %%
# Analyzing bulk file

blk_cdf = cdflib.CDF("../dataset/AL1_ASW91_L2_BLK_20250103_UNP_9999_999999_V02.cdf")

# Get CDF info
blk_info = blk_cdf.cdf_info()

# Access variable names using attributes (not dictionary keys)
print("Variables in Bulk file:")
print("zVariables:", blk_info.zVariables)
print("rVariables:", blk_info.rVariables)
# Out:
# Variables in Bulk file:
# zVariables: ['epoch_for_cdf_mod', 'proton_density', 'numden_p_uncer', 'proton_bulk_speed', 'bulk_p_uncer', 'proton_xvelocity', 'proton_yvelocity', 'proton_zvelocity', 'proton_thermal', 'thermal_p_uncer', 'alpha_density', 'numden_a_uncer', 'alpha_bulk_speed', 'bulk_a_uncer', 'alpha_thermal', 'thermal_a_uncer', 'spacecraft_xpos', 'spacecraft_ypos', 'spacecraft_zpos']
# rVariables: []

# %%
# Dynamically add each attribute as a separate column for each variable
attributes_list = [blk_cdf.varattsget(var) for var in blk_info.zVariables]
all_attr_keys = set()
for attrs in attributes_list:
    all_attr_keys.update(attrs.keys())

blk_variables_df = pd.DataFrame({"Variable": blk_info.zVariables})
for key in all_attr_keys:
    # To access or print the attributes for each variable:
    print(f"\nAttribute: {key}")
    for var, attrs in zip(blk_info.zVariables, attributes_list):
        print(f"  {var}: {attrs.get(key, None)} \n")
    # Add as column to DataFrame
    blk_variables_df[key] = [attrs.get(key, None) for attrs in attributes_list]
# Out:
# Attribute: SCALETYP
#   epoch_for_cdf_mod: linear
#
#   proton_density: linear
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: linear
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: linear
#
#   proton_yvelocity: linear
#
#   proton_zvelocity: linear
#
#   proton_thermal: linear
#
#   thermal_p_uncer: None
#
#   alpha_density: linear
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: linear
#
#   bulk_a_uncer: None
#
#   alpha_thermal: linear
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: linear
#
#   spacecraft_ypos: linear
#
#   spacecraft_zpos: linear
#
#
# Attribute: MONOTON
#   epoch_for_cdf_mod: INCREASE
#
#   proton_density: None
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: None
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: None
#
#   proton_yvelocity: None
#
#   proton_zvelocity: None
#
#   proton_thermal: None
#
#   thermal_p_uncer: None
#
#   alpha_density: None
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: None
#
#   bulk_a_uncer: None
#
#   alpha_thermal: None
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: None
#
#   spacecraft_ypos: None
#
#   spacecraft_zpos: None
#
#
# Attribute: VAR_NOTES
#   epoch_for_cdf_mod: The Epoch value is the number of milliseconds since 01-Jan-0000 00:00:00.000
#
#   proton_density: The proton number density is obtained from the level 2 flux data of SWIS-ASPEX. The value provided in this dataset is preliminary and the instrument team is working to obtain a more robust estimate of the number density.
#
#   numden_p_uncer: Tentative uncertainty of number density. Density uncertainty at present is derived from the propagation of error in flux values combined with the fitting errors. The value provided in the dataset is typical uncertainty in the density values corresponding to those errors. Higher errors in the derived parameters will reflect in the quality flag description provided in the dataset. Instrument team is working to obtain a more robust estimate of the number density uncertainty for onboard observations.
#
#   proton_bulk_speed: The proton bulk speed is obtained from the level 2 energy differentiated flux data of SWIS-ASPEX
#
#   bulk_p_uncer: Tentative uncertainty in bulk speed. Bulk speed uncertainty at present is derived from the propagation of error in energy values combined with the fitting errors. The value provided in the dataset is typical uncertainty in the bulk speed values corresponding to these errors. These will reflect in the quality flag description provided in the dataset. Instrument team is working to obtain a more robust estimate of the uncertainty for onboard observations.
#
#   proton_xvelocity: The proton xvelocity is obtained from the level 2 energy differentiated flux data of SWIS-ASPEX
#
#   proton_yvelocity: The proton yvelocity is obtained from the level 2 energy differentiated flux data of SWIS-ASPEX
#
#   proton_zvelocity: The proton zvelocity is obtained from the level 2 energy differentiated flux data of SWIS-ASPEX
#
#   proton_thermal: The proton thermal speed is obtained from the level 2 energy differentiated flux data of SWIS-ASPEX
#
#   thermal_p_uncer: Tentative uncertainty in proton thermal speed. Bulk speed uncertainty at present is derived from the propagation of error in energy values combined with the fitting errors. The value provided in the dataset is typical uncertainty in the thermal speed values corresponding to these errors. These will reflect in the quality flag description provided in the dataset. Instrument team is working to obtain a more robust estimate of the uncertainty for onboard observations.
#
#   alpha_density: The alpha number density is obtained from the level 2 flux data of SWIS-ASPEX. The value provided in this dataset is preliminary and the instrument team is working to obtain a more robust estimate of the number density.
#
#   numden_a_uncer: Tentative uncertainty of number density. Density uncertainty at present is derived from the propagation of error in flux values combined with the fitting errors. The value provided in the dataset is typical uncertainty in the density values corresponding to those errors. Higher errors in the derived parameters will reflect in the quality flag description provided in the dataset. Instrument team is working to obtain a more robust estimate of the number density uncertainty for onboard observations.
#
#   alpha_bulk_speed: The alpha bulk speed is obtained from the level 2 energy differentiated flux data of SWIS-ASPEX
#
#   bulk_a_uncer: Tentative uncertainty in bulk speed. Bulk speed uncertainty at present is derived from the propagation of error in energy values combined with the fitting errors. The value provided in the dataset is typical uncertainty in the bulk speed values corresponding to these errors. These will reflect in the quality flag description provided in the dataset. Instrument team is working to obtain a more robust estimate of the uncertainty for onboard observations.
#
#   alpha_thermal: The alpha thermal speed is obtained from the level 2 energy differentiated flux data of SWIS-ASPEX
#
#   thermal_a_uncer: Tentative uncertainty in alpha thermal speed. Bulk speed uncertainty at present is derived from the propagation of error in energy values combined with the fitting errors. The value provided in the dataset is typical uncertainty in the thermal speed values corresponding to these errors. These will reflect in the quality flag description provided in the dataset. Instrument team is working to obtain a more robust estimate of the uncertainty for onboard observations.
#
#   spacecraft_xpos: Spacecraft X-position in GSE coordinate system
#
#   spacecraft_ypos: Spacecraft Y-position in GSE coordinate system
#
#   spacecraft_zpos: Spacecraft Z-position in GSE coordinate system
#
#
# Attribute: LABLAXIS
#   epoch_for_cdf_mod: Epoch
#
#   proton_density: Proton number density
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: Proton bulk speed
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: Proton velocity along X-GSE
#
#   proton_yvelocity: Proton velocity along Y-GSE
#
#   proton_zvelocity: Proton velocity along Z-GSE
#
#   proton_thermal: Proton thermal speed
#
#   thermal_p_uncer: None
#
#   alpha_density: Alpha number density
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: Alpha bulk speed
#
#   bulk_a_uncer: None
#
#   alpha_thermal: Alpha thermal speed
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: POS_X_GSE
#
#   spacecraft_ypos: POS_Y_GSE
#
#   spacecraft_zpos: POS_Z_GSE
#
#
# Attribute: VALIDMIN
#   epoch_for_cdf_mod: 63864547200000.0
#
#   proton_density: 0.0
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: 0.0
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: 0.0
#
#   proton_yvelocity: 0.0
#
#   proton_zvelocity: 0.0
#
#   proton_thermal: 0.0
#
#   thermal_p_uncer: None
#
#   alpha_density: 0.0
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: 0.0
#
#   bulk_a_uncer: None
#
#   alpha_thermal: 0.0
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: -100000000.0
#
#   spacecraft_ypos: -100000000.0
#
#   spacecraft_zpos: -100000000.0
#
#
# Attribute: DEPEND_0
#   epoch_for_cdf_mod: epoch_for_cdf
#
#   proton_density: epoch_for_cdf
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: epoch_for_cdf
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: epoch_for_cdf
#
#   proton_yvelocity: epoch_for_cdf
#
#   proton_zvelocity: epoch_for_cdf
#
#   proton_thermal: epoch_for_cdf
#
#   thermal_p_uncer: None
#
#   alpha_density: epoch_for_cdf
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: epoch_for_cdf
#
#   bulk_a_uncer: None
#
#   alpha_thermal: epoch_for_cdf
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: epoch_for_cdf
#
#   spacecraft_ypos: epoch_for_cdf
#
#   spacecraft_zpos: epoch_for_cdf
#
#
# Attribute: SCALEMAX
#   epoch_for_cdf_mod: 0.5
#
#   proton_density: 100.0
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: 800.0
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: 800.0
#
#   proton_yvelocity: 800.0
#
#   proton_zvelocity: 800.0
#
#   proton_thermal: 100.0
#
#   thermal_p_uncer: None
#
#   alpha_density: 100.0
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: 800.0
#
#   bulk_a_uncer: None
#
#   alpha_thermal: 100.0
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: None
#
#   spacecraft_ypos: None
#
#   spacecraft_zpos: None
#
#
# Attribute: AVG_TYPE
#   epoch_for_cdf_mod: none
#
#   proton_density: None
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: None
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: None
#
#   proton_yvelocity: None
#
#   proton_zvelocity: None
#
#   proton_thermal: None
#
#   thermal_p_uncer: None
#
#   alpha_density: None
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: None
#
#   bulk_a_uncer: None
#
#   alpha_thermal: None
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: None
#
#   spacecraft_ypos: None
#
#   spacecraft_zpos: None
#
#
# Attribute: SI_conv
#   epoch_for_cdf_mod: None
#
#   proton_density: 1.0e6>m^-3
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: 1.0e3>m/sec
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: 1.0e3>m/sec
#
#   proton_yvelocity: 1.0e3>m/sec
#
#   proton_zvelocity: 1.0e3>m/sec
#
#   proton_thermal: 1.0e3>m/sec
#
#   thermal_p_uncer: None
#
#   alpha_density: 1.0e6>m^-3
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: 1.0e3>m/sec
#
#   bulk_a_uncer: None
#
#   alpha_thermal: 1.0e3>m/sec
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: 1.0e3>Meters
#
#   spacecraft_ypos: 1.0e3>Meters
#
#   spacecraft_zpos: 1.0e3>Meters
#
#
# Attribute: TIME_BASE
#   epoch_for_cdf_mod: 0AD
#
#   proton_density: None
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: None
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: None
#
#   proton_yvelocity: None
#
#   proton_zvelocity: None
#
#   proton_thermal: None
#
#   thermal_p_uncer: None
#
#   alpha_density: None
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: None
#
#   bulk_a_uncer: None
#
#   alpha_thermal: None
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: None
#
#   spacecraft_ypos: None
#
#   spacecraft_zpos: None
#
#
# Attribute: FILLVAL
#   epoch_for_cdf_mod: -1e+31
#
#   proton_density: -1e+31
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: -1e+31
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: -1e+31
#
#   proton_yvelocity: -1e+31
#
#   proton_zvelocity: -1e+31
#
#   proton_thermal: -1e+31
#
#   thermal_p_uncer: None
#
#   alpha_density: -1e+31
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: -1e+31
#
#   bulk_a_uncer: None
#
#   alpha_thermal: -1e+31
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: -1e+31
#
#   spacecraft_ypos: -1e+31
#
#   spacecraft_zpos: -1e+31
#
#
# Attribute: SCALEMIN
#   epoch_for_cdf_mod: 0.1
#
#   proton_density: 0.0
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: 200.0
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: 200.0
#
#   proton_yvelocity: 200.0
#
#   proton_zvelocity: 200.0
#
#   proton_thermal: 0.0
#
#   thermal_p_uncer: None
#
#   alpha_density: 0.0
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: 200.0
#
#   bulk_a_uncer: None
#
#   alpha_thermal: 0.0
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: None
#
#   spacecraft_ypos: None
#
#   spacecraft_zpos: None
#
#
# Attribute: sig_digits
#   epoch_for_cdf_mod: 4
#
#   proton_density: 2
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: 2
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: 2
#
#   proton_yvelocity: 2
#
#   proton_zvelocity: 2
#
#   proton_thermal: 2
#
#   thermal_p_uncer: None
#
#   alpha_density: 2
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: 2
#
#   bulk_a_uncer: None
#
#   alpha_thermal: 2
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: 2
#
#   spacecraft_ypos: 2
#
#   spacecraft_zpos: 2
#
#
# Attribute: DELTA_PLUS_VAR
#   epoch_for_cdf_mod: None
#
#   proton_density: numden_p_uncer
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: bulk_p_uncer
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: bulk_p_uncer
#
#   proton_yvelocity: bulk_p_uncer
#
#   proton_zvelocity: bulk_p_uncer
#
#   proton_thermal: thermal_p_uncer
#
#   thermal_p_uncer: None
#
#   alpha_density: numden_a_uncer
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: bulk_a_uncer
#
#   bulk_a_uncer: None
#
#   alpha_thermal: thermal_a_uncer
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: None
#
#   spacecraft_ypos: None
#
#   spacecraft_zpos: None
#
#
# Attribute: VALIDMAX
#   epoch_for_cdf_mod: 65480745600000.0
#
#   proton_density: 150.0
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: 1200.0
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: 1200.0
#
#   proton_yvelocity: 1200.0
#
#   proton_zvelocity: 1200.0
#
#   proton_thermal: 200.0
#
#   thermal_p_uncer: None
#
#   alpha_density: 150.0
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: 1200.0
#
#   bulk_a_uncer: None
#
#   alpha_thermal: 200.0
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: 100000000.0
#
#   spacecraft_ypos: 100000000.0
#
#   spacecraft_zpos: 100000000.0
#
#
# Attribute: VAR_TYPE
#   epoch_for_cdf_mod: support_data
#
#   proton_density: data
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: data
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: data
#
#   proton_yvelocity: data
#
#   proton_zvelocity: data
#
#   proton_thermal: data
#
#   thermal_p_uncer: None
#
#   alpha_density: data
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: data
#
#   bulk_a_uncer: None
#
#   alpha_thermal: data
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: data
#
#   spacecraft_ypos: data
#
#   spacecraft_zpos: data
#
#
# Attribute: UNITS
#   epoch_for_cdf_mod: sec
#
#   proton_density: #/cm3
#
#   numden_p_uncer: #/cm3
#
#   proton_bulk_speed: Km/sec
#
#   bulk_p_uncer: Km/sec
#
#   proton_xvelocity: Km/sec
#
#   proton_yvelocity: Km/sec
#
#   proton_zvelocity: Km/sec
#
#   proton_thermal: Km/sec
#
#   thermal_p_uncer: Km/sec
#
#   alpha_density: #/cm3
#
#   numden_a_uncer: #/cm3
#
#   alpha_bulk_speed: Km/sec
#
#   bulk_a_uncer: Km/sec
#
#   alpha_thermal: Km/sec
#
#   thermal_a_uncer: Km/sec
#
#   spacecraft_xpos: km
#
#   spacecraft_ypos: km
#
#   spacecraft_zpos: km
#
#
# Attribute: FORMAT
#   epoch_for_cdf_mod: None
#
#   proton_density: F3.2
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: F4.2
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: F4.2
#
#   proton_yvelocity: F4.2
#
#   proton_zvelocity: F4.2
#
#   proton_thermal: F3.2
#
#   thermal_p_uncer: None
#
#   alpha_density: F3.2
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: F4.2
#
#   bulk_a_uncer: None
#
#   alpha_thermal: F3.2
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: E8.5
#
#   spacecraft_ypos: E8.5
#
#   spacecraft_zpos: E8.5
#
#
# Attribute: DELTA_MINUS_VAR
#   epoch_for_cdf_mod: None
#
#   proton_density: numden_p_uncer
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: bulk_p_uncer
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: bulk_p_uncer
#
#   proton_yvelocity: bulk_p_uncer
#
#   proton_zvelocity: bulk_p_uncer
#
#   proton_thermal: thermal_p_uncer
#
#   thermal_p_uncer: None
#
#   alpha_density: numden_a_uncer
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: bulk_a_uncer
#
#   bulk_a_uncer: None
#
#   alpha_thermal: thermal_a_uncer
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: None
#
#   spacecraft_ypos: None
#
#   spacecraft_zpos: None
#
#
# Attribute: DISPLAY_TYPE
#   epoch_for_cdf_mod: no_plot
#
#   proton_density: time_series
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: time_series
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: time_series
#
#   proton_yvelocity: time_series
#
#   proton_zvelocity: time_series
#
#   proton_thermal: time_series
#
#   thermal_p_uncer: None
#
#   alpha_density: time_series
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: time_series
#
#   bulk_a_uncer: None
#
#   alpha_thermal: time_series
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: time_series
#
#   spacecraft_ypos: time_series
#
#   spacecraft_zpos: time_series
#
#
# Attribute: DICT_KEY
#   epoch_for_cdf_mod: time>Epoch
#
#   proton_density: density>number
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: velocity>speed
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: velocity>speed
#
#   proton_yvelocity: velocity>speed
#
#   proton_zvelocity: velocity>speed
#
#   proton_thermal: velocity>thermal
#
#   thermal_p_uncer: None
#
#   alpha_density: density>number
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: velocity>speed
#
#   bulk_a_uncer: None
#
#   alpha_thermal: velocity>thermal
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: position>distance
#
#   spacecraft_ypos: position>distance
#
#   spacecraft_zpos: position>distance
#
#
# Attribute: DERIVN
#   epoch_for_cdf_mod: None
#
#   proton_density: The number density values are derived from level 2 flux data from SWIS.
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: The bulk speed of protons are derived from non-linear fitting of level 2 flux data from SWIS.
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: The X velocity of protons are derived from non-linear fitting of level 2 flux data from SWIS.
#
#   proton_yvelocity: The Y velocity of protons are derived from non-linear fitting of level 2 flux data from SWIS.
#
#   proton_zvelocity: The Z velocity of protons are derived from non-linear fitting of level 2 flux data from SWIS.
#
#   proton_thermal: The thermal speed of protons are derived from non-linear fitting of level 2 flux data from SWIS.
#
#   thermal_p_uncer: None
#
#   alpha_density: The number density values are derived from level 2 flux data from SWIS.
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: The bulk speed of alpha particles are derived from non-linear fitting of level 2 flux data from SWIS.
#
#   bulk_a_uncer: None
#
#   alpha_thermal: The thermal speed of alpha particles are derived from non-linear fitting of level 2 flux data from SWIS.
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: The spacecraft position in GSE is derived from the processing of SPICE kernels provided by the FDG team.
#
#   spacecraft_ypos: The spacecraft position in GSE is derived from the processing of SPICE kernels provided by the FDG team.
#
#   spacecraft_zpos: The spacecraft position in GSE is derived from the processing of SPICE kernels provided by the FDG team.
#
#
# Attribute: VARIABLE_PURPOSE
#   epoch_for_cdf_mod: PRIMARY_VAR, Time
#
#   proton_density: Number_density
#
#   numden_p_uncer: None
#
#   proton_bulk_speed: Bulk_speed
#
#   bulk_p_uncer: None
#
#   proton_xvelocity: Velocity_component
#
#   proton_yvelocity: Velocity_component
#
#   proton_zvelocity: Velocity_component
#
#   proton_thermal: Thermal_speed
#
#   thermal_p_uncer: None
#
#   alpha_density: Number_density
#
#   numden_a_uncer: None
#
#   alpha_bulk_speed: Bulk_speed
#
#   bulk_a_uncer: None
#
#   alpha_thermal: Thermal_speed
#
#   thermal_a_uncer: None
#
#   spacecraft_xpos: Position_distance_spacecraft
#
#   spacecraft_ypos: Position_distance_spacecraft
#
#   spacecraft_zpos: Position_distance_spacecraft
#
#
# Attribute: CATDESC
#   epoch_for_cdf_mod: CDF Epoch time at the beginning of each energy measurement (milliseconds)
#
#   proton_density: Number density
#
#   numden_p_uncer: Number density uncertainty
#
#   proton_bulk_speed: Bulk speed
#
#   bulk_p_uncer: Bulk speed uncertainty
#
#   proton_xvelocity: Proton velocity
#
#   proton_yvelocity: Proton velocity
#
#   proton_zvelocity: Proton velocity
#
#   proton_thermal: Thermal speed
#
#   thermal_p_uncer: Thermal speed uncertainty
#
#   alpha_density: Number density
#
#   numden_a_uncer: Number density uncertainty
#
#   alpha_bulk_speed: Bulk speed
#
#   bulk_a_uncer: Bulk speed uncertainty
#
#   alpha_thermal: Thermal speed
#
#   thermal_a_uncer: Thermal speed uncertainty
#
#   spacecraft_xpos: Spacecraft X-Position in GSE
#
#   spacecraft_ypos: Spacecraft Y-Position in GSE
#
#   spacecraft_zpos: Spacecraft Z-Position in GSE
#
#
# Attribute: FIELDNAME
#   epoch_for_cdf_mod: Time of observation (UTC Epoch)
#
#   proton_density: Proton number density
#
#   numden_p_uncer: Proton number density uncertainty
#
#   proton_bulk_speed: Proton bulk speed
#
#   bulk_p_uncer: Proton bulk speed uncertainty
#
#   proton_xvelocity: Proton velocity along X-GSE
#
#   proton_yvelocity: Proton velocity along Y-GSE
#
#   proton_zvelocity: Proton velocity along Z-GSE
#
#   proton_thermal: Thermal speed of protons
#
#   thermal_p_uncer: Proton thermal speed uncertainty
#
#   alpha_density: Alpha number density
#
#   numden_a_uncer: Alpha number density uncertainty
#
#   alpha_bulk_speed: Alpha bulk speed
#
#   bulk_a_uncer: Alpha bulk speed uncertainty
#
#   alpha_thermal: Thermal speed of alpha particles
#
#   thermal_a_uncer: Alpha thermal speed uncertainty
#
#   spacecraft_xpos: Spacecraft Position_X - SWIS/ASPEX/Aditya-L1
#
#   spacecraft_ypos: Spacecraft Position_Y - SWIS/ASPEX/Aditya-L1
#
#   spacecraft_zpos: Spacecraft Position_Z - SWIS/ASPEX/Aditya-L1

# %%
# Getting detailed information about variables from bulk file

print("Detailed Variable Information of blk file:")
print("=" * 50)

for var in blk_info.zVariables:
    var_info = blk_cdf.varinq(var)
    print(f"\nVariable: {var}")
    print(f"  Data Type: {var_info.Data_Type_Description}")
    print(f"  Dimensions: {var_info.Dim_Sizes}")
    
    # Show all available attributes of var_info
    print(f"  Available info: {[attr for attr in dir(var_info) if not attr.startswith('_')]}")
    
    # Get the actual data to see its shape and content
    try:
        data = blk_cdf[var][:]
        print(f"  Data shape: {data.shape}")
        print(f"  Data type: {type(data)}")
        
        # Show first few values if it's a simple array
        if data.size <= 20:  # Small arrays - show all
            print(f"  Data: {data}")
        else:  # Large arrays - show sample
            print(f"  First 5 values: {data.flat[:5] if hasattr(data, 'flat') else 'N/A'}")
            
    except Exception as e:
        print(f"  Error reading data: {str(e)}")
# Out:
# Detailed Variable Information of blk file:
# ==================================================
#
# Variable: epoch_for_cdf_mod
#   Data Type: CDF_EPOCH
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [6.39030816e+13 6.39030816e+13 6.39030816e+13 6.39030816e+13
#  6.39030816e+13]
#
# Variable: proton_density
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [12.12578549 13.16558561 13.45022251 11.7010548  12.66298844]
#
# Variable: numden_p_uncer
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [-1.e+31 -1.e+31 -1.e+31 -1.e+31 -1.e+31]
#
# Variable: proton_bulk_speed
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [469.73877717 469.84176796 469.55381259 469.52344855 470.0172466 ]
#
# Variable: bulk_p_uncer
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [-1.e+31 -1.e+31 -1.e+31 -1.e+31 -1.e+31]
#
# Variable: proton_xvelocity
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [-469.73877717 -469.84176796 -469.55381259 -469.52344855 -470.0172466 ]
#
# Variable: proton_yvelocity
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [ 14.9309415  -21.17755428  -4.99828516 -56.97021861 -25.0899463 ]
#
# Variable: proton_zvelocity
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [ 0.94315292  4.94432725  1.02213276  2.82822431 -0.32332214]
#
# Variable: proton_thermal
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [21.1668457  20.61136193 20.49132326 21.02244526 20.87515844]
#
# Variable: thermal_p_uncer
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [-1.e+31 -1.e+31 -1.e+31 -1.e+31 -1.e+31]
#
# Variable: alpha_density
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [0.31574027 0.31257854 0.31161408 0.309863   0.35122335]
#
# Variable: numden_a_uncer
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [-1.e+31 -1.e+31 -1.e+31 -1.e+31 -1.e+31]
#
# Variable: alpha_bulk_speed
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [474.67463086 474.68837069 474.67639022 474.65061578 476.69308437]
#
# Variable: bulk_a_uncer
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [-1.e+31 -1.e+31 -1.e+31 -1.e+31 -1.e+31]
#
# Variable: alpha_thermal
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [22.73275098 22.29918606 22.48591414 22.71240745 22.99888772]
#
# Variable: thermal_a_uncer
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [-1.e+31 -1.e+31 -1.e+31 -1.e+31 -1.e+31]
#
# Variable: spacecraft_xpos
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [1230121.69106197 1230121.68788131 1230121.68470051 1230121.68151935
#  1230121.67833813]
#
# Variable: spacecraft_ypos
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [169786.57849598 169788.07278031 169789.56706323 169791.06137467
#  169792.55565485]
#
# Variable: spacecraft_zpos
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17275,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [-100957.4555139  -100957.3731778  -100957.29084095 -100957.20850184
#  -100957.12616367]

# %%
# Analyzing THA-1 file
# Top Hat Analyser-1 (THA-1): Designed for species differentiation (H+ and He++) in the ecliptic plane6.... 
# It uses an electrostatic energy analyzer (ESA) combined with a magnetic mass analyzer (MMA)1015.

tha1_cdf = cdflib.CDF("../dataset/AL1_ASW91_L2_TH1_20250615_UNP_9999_999999_V02.cdf")

# Get CDF info
tha1_info = tha1_cdf.cdf_info()

# Access variable names using attributes (not dictionary keys)
print("Variables in THA-1 file:")
print("zVariables:", tha1_info.zVariables)
print("rVariables:", tha1_info.rVariables)
# Out:
# Variables in THA-1 file:
# zVariables: ['epoch_for_cdf_mod', 'energy_center_mod', 'energy_uncer', 'integrated_flux_mod', 'flux_uncer', 'integrated_flux_s9_mod', 'integrated_flux_s10_mod', 'integrated_flux_s11_mod', 'spacecraft_xpos', 'spacecraft_ypos', 'spacecraft_zpos', 'sun_angle_tha1']
# rVariables: []

# %%
# Getting detailed information about variables from THA-1 file

print("Detailed Variable Information of THA-1 file:")
print("=" * 50)

for var in tha1_info.zVariables:
    var_info = tha1_cdf.varinq(var)
    print(f"\nVariable: {var}")
    print(f"  Data Type: {var_info.Data_Type_Description}")
    print(f"  Dimensions: {var_info.Dim_Sizes}")
    
    # Show all available attributes of var_info
    print(f"  Available info: {[attr for attr in dir(var_info) if not attr.startswith('_')]}")
    
    # Get the actual data to see its shape and content
    try:
        data = tha1_cdf[var][:]
        print(f"  Data shape: {data.shape}")
        print(f"  Data type: {type(data)}")
        
        # Show first few values if it's a simple array
        if data.size <= 20:  # Small arrays - show all
            print(f"  Data: {data}")
        else:  # Large arrays - show sample
            print(f"  First 5 values: {data.flat[:5] if hasattr(data, 'flat') else 'N/A'}")
            
    except Exception as e:
        print(f"  Error reading data: {str(e)}")
# Out:
# Detailed Variable Information of THA-1 file:
# ==================================================
#
# Variable: epoch_for_cdf_mod
#   Data Type: CDF_EPOCH
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [6.39171648e+13 6.39171648e+13 6.39171648e+13 6.39171648e+13
#  6.39171649e+13]
#
# Variable: energy_center_mod
#   Data Type: CDF_DOUBLE
#   Dimensions: [50]
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194, 50)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [125.93289039 136.69067051 147.44845064 168.96401088 179.72179101]
#
# Variable: energy_uncer
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Error reading data: invalid index to scalar variable.
#
# Variable: integrated_flux_mod
#   Data Type: CDF_DOUBLE
#   Dimensions: [50]
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194, 50)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [103031.69098909             nan             nan  93593.820924
#  313646.62900355]
#
# Variable: flux_uncer
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Error reading data: invalid index to scalar variable.
#
# Variable: integrated_flux_s9_mod
#   Data Type: CDF_DOUBLE
#   Dimensions: [50]
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194, 50)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [nan nan nan nan nan]
#
# Variable: integrated_flux_s10_mod
#   Data Type: CDF_DOUBLE
#   Dimensions: [50]
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194, 50)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [4114242.63837681 4105215.22237222 4079897.07602318 1970772.37059702
#  2033712.81227383]
#
# Variable: integrated_flux_s11_mod
#   Data Type: CDF_DOUBLE
#   Dimensions: [50]
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194, 50)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [nan nan nan nan nan]
#
# Variable: spacecraft_xpos
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [1269675.63883311 1269675.64387666 1269675.64892115 1269675.65396644
#  1269675.65901254]
#
# Variable: spacecraft_ypos
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [-200768.83616764 -200767.48724121 -200766.13825927 -200764.78933016
#  -200763.44039938]
#
# Variable: spacecraft_zpos
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [-101561.97542657 -101562.05284215 -101562.13026018 -101562.20767453
#  -101562.28508827]
#
# Variable: sun_angle_tha1
#   Data Type: CDF_DOUBLE
#   Dimensions: [16, 3]
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194, 16, 3)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [ 9.25458746e-01  9.99990994e-01 -5.30261529e-05 -3.78847865e-01
#   8.99441370e-04]

# %%
# Analyzing THA-2 file
# Measures the total flux (species integrated mode) across the ecliptic plane6.... It uses an ESA but does not contain an MMA

tha2_cdf = cdflib.CDF("../dataset/AL1_ASW91_L2_TH2_20250615_UNP_9999_999999_V02.cdf")

# Get CDF info
tha2_info = tha2_cdf.cdf_info()

# Access variable names using attributes (not dictionary keys)
print("Variables in THA-2 file:")
print("zVariables:", tha2_info.zVariables)
print("rVariables:", tha2_info.rVariables)
# Out:
# Variables in THA-2 file:
# zVariables: ['epoch_for_cdf_mod', 'energy_center_mod', 'energy_uncer', 'integrated_flux_mod', 'flux_uncer', 'integrated_flux_s15_mod', 'integrated_flux_s16_mod', 'integrated_flux_s17_mod', 'integrated_flux_s18_mod', 'integrated_flux_s19_mod', 'spacecraft_xpos', 'spacecraft_ypos', 'spacecraft_zpos', 'sun_angle_tha2']
# rVariables: []

# %%
# Getting detailed information about variables from THA-2 file

print("Detailed Variable Information of THA-2 file:")
print("=" * 50)

for var in tha2_info.zVariables:
    var_info = tha2_cdf.varinq(var)
    print(f"\nVariable: {var}")
    print(f"  Data Type: {var_info.Data_Type_Description}")
    print(f"  Dimensions: {var_info.Dim_Sizes}")
    
    # Show all available attributes of var_info
    print(f"  Available info: {[attr for attr in dir(var_info) if not attr.startswith('_')]}")
    
    # Get the actual data to see its shape and content
    try:
        data = tha2_cdf[var][:]
        print(f"  Data shape: {data.shape}")
        print(f"  Data type: {type(data)}")
        
        # Show first few values if it's a simple array
        if data.size <= 20:  # Small arrays - show all
            print(f"  Data: {data}")
        else:  # Large arrays - show sample
            print(f"  First 5 values: {data.flat[:5] if hasattr(data, 'flat') else 'N/A'}")
            
    except Exception as e:
        print(f"  Error reading data: {str(e)}")
# Out:
# Detailed Variable Information of THA-2 file:
# ==================================================
#
# Variable: epoch_for_cdf_mod
#   Data Type: CDF_EPOCH
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [6.39171648e+13 6.39171648e+13 6.39171648e+13 6.39171648e+13
#  6.39171649e+13]
#
# Variable: energy_center_mod
#   Data Type: CDF_DOUBLE
#   Dimensions: [50]
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194, 50)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [172.50130344 183.24450193 193.98770042 215.47409739 226.21729588]
#
# Variable: energy_uncer
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Error reading data: invalid index to scalar variable.
#
# Variable: integrated_flux_mod
#   Data Type: CDF_DOUBLE
#   Dimensions: [50]
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194, 50)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [1411458.33333333              nan              nan              nan
#   936458.33333334]
#
# Variable: flux_uncer
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Error reading data: invalid index to scalar variable.
#
# Variable: integrated_flux_s15_mod
#   Data Type: CDF_DOUBLE
#   Dimensions: [50]
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194, 50)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [             nan 4066666.66666667  933333.33333333 1000000.
#               nan]
#
# Variable: integrated_flux_s16_mod
#   Data Type: CDF_DOUBLE
#   Dimensions: [50]
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194, 50)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [3666666.66666667  400000.         3533333.33333333              nan
#   733333.33333333]
#
# Variable: integrated_flux_s17_mod
#   Data Type: CDF_DOUBLE
#   Dimensions: [50]
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194, 50)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [16933333.33333334               nan               nan               nan
#   2000000.        ]
#
# Variable: integrated_flux_s18_mod
#   Data Type: CDF_DOUBLE
#   Dimensions: [50]
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194, 50)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [ 4900000.                       nan               nan  2100000.
#  13033333.33333334]
#
# Variable: integrated_flux_s19_mod
#   Data Type: CDF_DOUBLE
#   Dimensions: [50]
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194, 50)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [nan nan nan nan nan]
#
# Variable: spacecraft_xpos
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [1269675.63883311 1269675.64387666 1269675.64892115 1269675.65396644
#  1269675.65901254]
#
# Variable: spacecraft_ypos
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [-200768.83616764 -200767.48724121 -200766.13825927 -200764.78933016
#  -200763.44039938]
#
# Variable: spacecraft_zpos
#   Data Type: CDF_DOUBLE
#   Dimensions: []
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194,)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [-101561.97542657 -101562.05284215 -101562.13026018 -101562.20767453
#  -101562.28508827]
#
# Variable: sun_angle_tha2
#   Data Type: CDF_DOUBLE
#   Dimensions: [32, 3]
#   Available info: ['Block_Factor', 'Compress', 'Data_Type', 'Data_Type_Description', 'Dim_Sizes', 'Dim_Vary', 'Last_Rec', 'Num', 'Num_Dims', 'Num_Elements', 'Pad', 'Rec_Vary', 'Sparse', 'Var_Type', 'Variable']
#   Data shape: (17194, 32, 3)
#   Data type: <class 'numpy.ndarray'>
#   First 5 values: [ 0.99999135 -0.9237585  -0.00305119  0.00414786 -0.55583058]

# %% [markdown]
# # Time series plots

# %% [markdown]
# ### For blk file

# %%
# Extract blk variables
epoch = blk_cdf['epoch_for_cdf_mod'][:]
time = cdflib.cdfepoch.to_datetime(epoch)
proton_density = blk_cdf['proton_density'][:]
proton_speed = blk_cdf['proton_bulk_speed'][:]
alpha_density = blk_cdf['alpha_density'][:]

# Create DataFrame
df = pd.DataFrame({
    "UTC": time,
    "Proton_Density": proton_density,
    "Proton_Bulk_Speed": proton_speed,
    "Alpha_Density": alpha_density
})

FILLVAL = -1e31  # Use exact value from the file for robustness

# Mask invalid rows
df_clean = df[(df["Proton_Density"] != FILLVAL) &
              (df["Proton_Bulk_Speed"] != FILLVAL) &
              (df["Alpha_Density"] != FILLVAL)].copy()

df = df_clean
print("DataFrame after cleaning:")
print(df.head())
# Out:
# DataFrame after cleaning:
#                       UTC  Proton_Density  Proton_Bulk_Speed  Alpha_Density
# 0 2025-01-03 00:00:28.509       12.125785         469.738777       0.315740
# 1 2025-01-03 00:00:33.509       13.165586         469.841768       0.312579
# 2 2025-01-03 00:00:38.509       13.450223         469.553813       0.311614
# 3 2025-01-03 00:00:43.509       11.701055         469.523449       0.309863
# 4 2025-01-03 00:00:48.509       12.662988         470.017247       0.351223

# %% [markdown]
# ##### Plot Proton Density

# %%
plt.figure(figsize=(10, 4))
plt.plot(df["UTC"], df["Proton_Density"], color='steelblue')
plt.xlabel("UTC Time")
plt.ylabel("Proton Density [cm⁻³]")
plt.title("Proton Density vs Time")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot Proton Bulk Speed

# %%
plt.figure(figsize=(10, 4))
plt.plot(df["UTC"], df["Proton_Bulk_Speed"], color='darkorange')
plt.xlabel("UTC Time")
plt.ylabel("Proton Bulk Speed [km/s]")
plt.title("Proton Bulk Speed vs Time")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot Alpha Density

# %%
plt.figure(figsize=(10, 4))
plt.plot(df["UTC"], df["Alpha_Density"], color='mediumseagreen')
plt.xlabel("UTC Time")
plt.ylabel("Alpha Density [cm⁻³]")
plt.title("Alpha Particle (He²⁺) Density vs Time")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Plot He²⁺ / H⁺ Ratio

# %%
df["He2p_Hp_Ratio"] = df["Alpha_Density"] / df["Proton_Density"]

plt.figure(figsize=(10, 4))
plt.plot(df["UTC"], df["He2p_Hp_Ratio"], color='indigo')
plt.xlabel("UTC Time")
plt.ylabel("He²⁺ / H⁺ Ratio")
plt.title("Alpha-to-Proton Density Ratio vs Time")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Combined:

# %%
fig, axs = plt.subplots(2, 2, figsize=(14, 8), sharex=True)

# Proton Density
axs[0, 0].plot(df["UTC"], df["Proton_Density"], color='steelblue')
axs[0, 0].set_ylabel("Proton Density [cm⁻³]")
axs[0, 0].set_title("Proton Density vs Time")
axs[0, 0].grid(True)

# Proton Bulk Speed
axs[0, 1].plot(df["UTC"], df["Proton_Bulk_Speed"], color='darkorange')
axs[0, 1].set_ylabel("Proton Bulk Speed [km/s]")
axs[0, 1].set_title("Proton Bulk Speed vs Time")
axs[0, 1].grid(True)

# Alpha Density
axs[1, 0].plot(df["UTC"], df["Alpha_Density"], color='mediumseagreen')
axs[1, 0].set_xlabel("UTC Time")
axs[1, 0].set_ylabel("Alpha Density [cm⁻³]")
axs[1, 0].set_title("Alpha Particle (He²⁺) Density vs Time")
axs[1, 0].grid(True)

# He²⁺ / H⁺ Ratio
axs[1, 1].plot(df["UTC"], df["He2p_Hp_Ratio"], color='indigo')
axs[1, 1].set_xlabel("UTC Time")
axs[1, 1].set_ylabel("He²⁺ / H⁺ Ratio")
axs[1, 1].set_title("Alpha-to-Proton Density Ratio vs Time")
axs[1, 1].grid(True)

plt.tight_layout()
plt.suptitle("BLK FILE", fontsize=18, y=1.02)
plt.show()

# %% [markdown]
# # HeatMap

# %%
# Create correlation heatmap with normalized data from all CDF files
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from scipy.stats import zscore

# Initialize dictionary to store all data
all_data = {}

# Extract data from Bulk file (INCLUDING ALL VARIABLES)
print("Extracting data from Bulk file...")
for var in blk_info.zVariables:
    try:
        data = blk_cdf[var][:]
        # Handle multidimensional data by taking mean if needed
        if data.ndim > 1:
            data = np.mean(data, axis=tuple(range(1, data.ndim)))
        all_data[f'BLK_{var}'] = data.flatten()
        print(f"  ✓ Added BLK_{var}")
    except Exception as e:
        print(f"  ✗ Error extracting {var} from bulk: {e}")

# Extract data from THA-1 file (INCLUDING ALL VARIABLES)
print("\nExtracting data from THA-1 file...")
for var in tha1_info.zVariables:
    try:
        data = tha1_cdf[var][:]
        # Handle multidimensional data by taking mean if needed
        if data.ndim > 1:
            data = np.mean(data, axis=tuple(range(1, data.ndim)))
        all_data[f'THA1_{var}'] = data.flatten()
        print(f"  ✓ Added THA1_{var}")
    except Exception as e:
        print(f"  ✗ Error extracting {var} from THA-1: {e}")

# Extract data from THA-2 file (INCLUDING ALL VARIABLES)
print("\nExtracting data from THA-2 file...")
for var in tha2_info.zVariables:
    try:
        data = tha2_cdf[var][:]
        # Handle multidimensional data by taking mean if needed
        if data.ndim > 1:
            data = np.mean(data, axis=tuple(range(1, data.ndim)))
        all_data[f'THA2_{var}'] = data.flatten()
        print(f"  ✓ Added THA2_{var}")
    except Exception as e:
        print(f"  ✗ Error extracting {var} from THA-2: {e}")

# Find the minimum length across all variables to ensure consistent array sizes
min_length = min(len(data) for data in all_data.values())
print(f"\nMinimum data length: {min_length}")

# Truncate all arrays to the same length
for key in all_data:
    all_data[key] = all_data[key][:min_length]

# Create DataFrame
df = pd.DataFrame(all_data)
print(f"\nDataFrame created with shape: {df.shape}")
print(f"Initial columns: {list(df.columns)}")

# Check for problematic values before cleaning
print(f"\nData quality check:")
columns_with_nan = df.columns[df.isna().any()].tolist()
columns_with_inf = df.columns[df.isin([np.inf, -np.inf]).any()].tolist()

print(f"Columns with NaN values: {columns_with_nan}")
print(f"Columns with infinite values: {columns_with_inf}")

# Handle problematic values with imputation instead of dropping columns
print(f"\nData cleaning strategy:")
print("- Replacing infinite values with NaN")
print("- Handling completely empty columns separately")
print("- Imputing NaN values with column median for partially filled columns")
print("- Keeping ALL columns including epoch_for_cdf_mod, integrated_flux_mod, energy_center_mod")

# Replace infinite values with NaN
df = df.replace([np.inf, -np.inf], np.nan)

# Check for completely empty columns (all NaN)
completely_empty_cols = df.columns[df.isna().all()].tolist()
partially_empty_cols = df.columns[df.isna().any() & ~df.isna().all()].tolist()

print(f"Completely empty columns (all NaN): {completely_empty_cols}")
print(f"Partially empty columns (some NaN): {partially_empty_cols}")

# Handle completely empty columns by filling with zeros
for col in completely_empty_cols:
    df[col] = 0.0
    print(f"  - Filled {col} with zeros")

# For time variables (epoch_for_cdf_mod), use forward fill first, then median
time_columns = [col for col in df.columns if 'epoch_for_cdf_mod' in col]
for col in time_columns:
    if col in partially_empty_cols:
        df[col] = df[col].ffill().bfill()
        print(f"  - Forward/backward filled {col}")

# Apply median imputation to remaining columns with partial NaN values
remaining_nan_cols = df.columns[df.isna().any()].tolist()
if remaining_nan_cols:
    print(f"Applying median imputation to: {remaining_nan_cols}")
    from sklearn.impute import SimpleImputer
    imputer = SimpleImputer(strategy='median')
    
    # Apply imputation only to columns that still have NaN
    df[remaining_nan_cols] = imputer.fit_transform(df[remaining_nan_cols])

print(f"\nImputation results:")
print(f"Total columns: {len(df.columns)}")
print(f"Remaining NaN values: {df.isna().sum().sum()}")

# Verify all requested columns are present
requested_cols = ['epoch_for_cdf_mod', 'integrated_flux_mod', 'energy_center_mod']
present_cols = []
for req_col in requested_cols:
    matching_cols = [col for col in df.columns if req_col in col]
    present_cols.extend(matching_cols)

print(f"Requested columns now included: {present_cols}")
print(f"Final dataset shape: {df.shape}")
print(f"Variables included: {list(df.columns)}")

# Normalize the data using Z-score normalization
df_normalized = df.apply(zscore, nan_policy='omit')

# Calculate correlation matrix
correlation_matrix = df_normalized.corr()

# Create the heatmap
plt.figure(figsize=(20, 16))
sns.heatmap(correlation_matrix, 
            annot=True, 
            cmap='RdYlBu_r', 
            center=0,
            square=True,
            fmt='.2f',
            cbar_kws={'label': 'Correlation Coefficient'},
            annot_kws={'size': 8})

plt.title('Correlation Heatmap of Normalized Data from All CDF Files\n(BLK: Bulk, THA1: Top Hat Analyzer-1, THA2: Top Hat Analyzer-2)', 
          fontsize=16, pad=20)
plt.xlabel('Variables', fontsize=12)
plt.ylabel('Variables', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# Print summary statistics
print("\nSummary of correlations:")
print("=" * 50)

# Find highest correlations (excluding self-correlations)
correlation_pairs = []
for i in range(len(correlation_matrix.columns)):
    for j in range(i+1, len(correlation_matrix.columns)):
        corr_val = correlation_matrix.iloc[i, j]
        if not np.isnan(corr_val):
            correlation_pairs.append((
                correlation_matrix.columns[i],
                correlation_matrix.columns[j],
                corr_val
            ))

# Sort by absolute correlation value
correlation_pairs.sort(key=lambda x: abs(x[2]), reverse=True)

print("Top 10 highest correlations:")
for i, (var1, var2, corr) in enumerate(correlation_pairs[:10]):
    print(f"{i+1:2d}. {var1} ↔ {var2}: {corr:.3f}")

print(f"\nTotal number of variable pairs analyzed: {len(correlation_pairs)}")
# Out:
# Extracting data from Bulk file...
#   ✓ Added BLK_epoch_for_cdf_mod
#   ✓ Added BLK_proton_density
#   ✓ Added BLK_numden_p_uncer
#   ✓ Added BLK_proton_bulk_speed
#   ✓ Added BLK_bulk_p_uncer
#   ✓ Added BLK_proton_xvelocity
#   ✓ Added BLK_proton_yvelocity
#   ✓ Added BLK_proton_zvelocity
#   ✓ Added BLK_proton_thermal
#   ✓ Added BLK_thermal_p_uncer
#   ✓ Added BLK_alpha_density
#   ✓ Added BLK_numden_a_uncer
#   ✓ Added BLK_alpha_bulk_speed
#   ✓ Added BLK_bulk_a_uncer
#   ✓ Added BLK_alpha_thermal
#   ✓ Added BLK_thermal_a_uncer
#   ✓ Added BLK_spacecraft_xpos
#   ✓ Added BLK_spacecraft_ypos
#   ✓ Added BLK_spacecraft_zpos
#
# Extracting data from THA-1 file...
#   ✓ Added THA1_epoch_for_cdf_mod
#   ✓ Added THA1_energy_center_mod
#   ✗ Error extracting energy_uncer from THA-1: invalid index to scalar variable.
#   ✓ Added THA1_integrated_flux_mod
#   ✗ Error extracting flux_uncer from THA-1: invalid index to scalar variable.
#   ✓ Added THA1_integrated_flux_s9_mod
#   ✓ Added THA1_integrated_flux_s10_mod
#   ✓ Added THA1_integrated_flux_s11_mod
#   ✓ Added THA1_spacecraft_xpos
#   ✓ Added THA1_spacecraft_ypos
#   ✓ Added THA1_spacecraft_zpos
#   ✓ Added THA1_sun_angle_tha1
#
# Extracting data from THA-2 file...
#   ✓ Added THA2_epoch_for_cdf_mod
#   ✓ Added THA2_energy_center_mod
#   ✗ Error extracting energy_uncer from THA-2: invalid index to scalar variable.
#   ✓ Added THA2_integrated_flux_mod
#   ✗ Error extracting flux_uncer from THA-2: invalid index to scalar variable.
#   ✓ Added THA2_integrated_flux_s15_mod
#   ✓ Added THA2_integrated_flux_s16_mod
#   ✓ Added THA2_integrated_flux_s17_mod
#   ✓ Added THA2_integrated_flux_s18_mod
#   ✓ Added THA2_integrated_flux_s19_mod
#   ✓ Added THA2_spacecraft_xpos
#   ✓ Added THA2_spacecraft_ypos
#   ✓ Added THA2_spacecraft_zpos
#   ✓ Added THA2_sun_angle_tha2
#
# Minimum data length: 17194
#
# DataFrame created with shape: (17194, 41)
# Initial columns: ['BLK_epoch_for_cdf_mod', 'BLK_proton_density', 'BLK_numden_p_uncer', 'BLK_proton_bulk_speed', 'BLK_bulk_p_uncer', 'BLK_proton_xvelocity', 'BLK_proton_yvelocity', 'BLK_proton_zvelocity', 'BLK_proton_thermal', 'BLK_thermal_p_uncer', 'BLK_alpha_density', 'BLK_numden_a_uncer', 'BLK_alpha_bulk_speed', 'BLK_bulk_a_uncer', 'BLK_alpha_thermal', 'BLK_thermal_a_uncer', 'BLK_spacecraft_xpos', 'BLK_spacecraft_ypos', 'BLK_spacecraft_zpos', 'THA1_epoch_for_cdf_mod', 'THA1_energy_center_mod', 'THA1_integrated_flux_mod', 'THA1_integrated_flux_s9_mod', 'THA1_integrated_flux_s10_mod', 'THA1_integrated_flux_s11_mod', 'THA1_spacecraft_xpos', 'THA1_spacecraft_ypos', 'THA1_spacecraft_zpos', 'THA1_sun_angle_tha1', 'THA2_epoch_for_cdf_mod', 'THA2_energy_center_mod', 'THA2_integrated_flux_mod', 'THA2_integrated_flux_s15_mod', 'THA2_integrated_flux_s16_mod', 'THA2_integrated_flux_s17_mod', 'THA2_integrated_flux_s18_mod', 'THA2_integrated_flux_s19_mod', 'THA2_spacecraft_xpos', 'THA2_spacecraft_ypos', 'THA2_spacecraft_zpos', 'THA2_sun_angle_tha2']
#
# Data quality check:
# Columns with NaN values: ['THA1_energy_center_mod', 'THA1_integrated_flux_mod', 'THA1_integrated_flux_s9_mod', 'THA1_integrated_flux_s10_mod', 'THA1_integrated_flux_s11_mod', 'THA2_energy_center_mod', 'THA2_integrated_flux_mod', 'THA2_integrated_flux_s15_mod', 'THA2_integrated_flux_s16_mod', 'THA2_integrated_flux_s17_mod', 'THA2_integrated_flux_s18_mod', 'THA2_integrated_flux_s19_mod']
# Columns with infinite values: []
#
# Data cleaning strategy:
# - Replacing infinite values with NaN
# - Handling completely empty columns separately
# - Imputing NaN values with column median for partially filled columns
# - Keeping ALL columns including epoch_for_cdf_mod, integrated_flux_mod, energy_center_mod
# Completely empty columns (all NaN): ['THA1_integrated_flux_s9_mod', 'THA1_integrated_flux_s11_mod', 'THA2_integrated_flux_s18_mod']
# Partially empty columns (some NaN): ['THA1_energy_center_mod', 'THA1_integrated_flux_mod', 'THA1_integrated_flux_s10_mod', 'THA2_energy_center_mod', 'THA2_integrated_flux_mod', 'THA2_integrated_flux_s15_mod', 'THA2_integrated_flux_s16_mod', 'THA2_integrated_flux_s17_mod', 'THA2_integrated_flux_s19_mod']
#   - Filled THA1_integrated_flux_s9_mod with zeros
#   - Filled THA1_integrated_flux_s11_mod with zeros
#   - Filled THA2_integrated_flux_s18_mod with zeros
# Applying median imputation to: ['THA1_energy_center_mod', 'THA1_integrated_flux_mod', 'THA1_integrated_flux_s10_mod', 'THA2_energy_center_mod', 'THA2_integrated_flux_mod', 'THA2_integrated_flux_s15_mod', 'THA2_integrated_flux_s16_mod', 'THA2_integrated_flux_s17_mod', 'THA2_integrated_flux_s19_mod']
#
# Imputation results:
# Total columns: 41
# Remaining NaN values: 0
# Requested columns now included: ['BLK_epoch_for_cdf_mod', 'THA1_epoch_for_cdf_mod', 'THA2_epoch_for_cdf_mod', 'THA1_integrated_flux_mod', 'THA2_integrated_flux_mod', 'THA1_energy_center_mod', 'THA2_energy_center_mod']
# Final dataset shape: (17194, 41)
# Variables included: ['BLK_epoch_for_cdf_mod', 'BLK_proton_density', 'BLK_numden_p_uncer', 'BLK_proton_bulk_speed', 'BLK_bulk_p_uncer', 'BLK_proton_xvelocity', 'BLK_proton_yvelocity', 'BLK_proton_zvelocity', 'BLK_proton_thermal', 'BLK_thermal_p_uncer', 'BLK_alpha_density', 'BLK_numden_a_uncer', 'BLK_alpha_bulk_speed', 'BLK_bulk_a_uncer', 'BLK_alpha_thermal', 'BLK_thermal_a_uncer', 'BLK_spacecraft_xpos', 'BLK_spacecraft_ypos', 'BLK_spacecraft_zpos', 'THA1_epoch_for_cdf_mod', 'THA1_energy_center_mod', 'THA1_integrated_flux_mod', 'THA1_integrated_flux_s9_mod', 'THA1_integrated_flux_s10_mod', 'THA1_integrated_flux_s11_mod', 'THA1_spacecraft_xpos', 'THA1_spacecraft_ypos', 'THA1_spacecraft_zpos', 'THA1_sun_angle_tha1', 'THA2_epoch_for_cdf_mod', 'THA2_energy_center_mod', 'THA2_integrated_flux_mod', 'THA2_integrated_flux_s15_mod', 'THA2_integrated_flux_s16_mod', 'THA2_integrated_flux_s17_mod', 'THA2_integrated_flux_s18_mod', 'THA2_integrated_flux_s19_mod', 'THA2_spacecraft_xpos', 'THA2_spacecraft_ypos', 'THA2_spacecraft_zpos', 'THA2_sun_angle_tha2']
# d:\Code\Python Projects\isro_bah_2025\venv\Lib\site-packages\pandas\core\apply.py:1081: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   results[i] = self.func(v, *self.args, **self.kwargs)
# d:\Code\Python Projects\isro_bah_2025\venv\Lib\site-packages\pandas\core\apply.py:1081: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   results[i] = self.func(v, *self.args, **self.kwargs)
# d:\Code\Python Projects\isro_bah_2025\venv\Lib\site-packages\pandas\core\apply.py:1081: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   results[i] = self.func(v, *self.args, **self.kwargs)
# d:\Code\Python Projects\isro_bah_2025\venv\Lib\site-packages\pandas\core\apply.py:1081: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   results[i] = self.func(v, *self.args, **self.kwargs)
# d:\Code\Python Projects\isro_bah_2025\venv\Lib\site-packages\pandas\core\apply.py:1081: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   results[i] = self.func(v, *self.args, **self.kwargs)
# d:\Code\Python Projects\isro_bah_2025\venv\Lib\site-packages\pandas\core\apply.py:1081: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   results[i] = self.func(v, *self.args, **self.kwargs)
# d:\Code\Python Projects\isro_bah_2025\venv\Lib\site-packages\pandas\core\apply.py:1081: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   results[i] = self.func(v, *self.args, **self.kwargs)
# d:\Code\Python Projects\isro_bah_2025\venv\Lib\site-packages\pandas\core\apply.py:1081: RuntimeWarning: Precision loss occurred in moment calculation due to catastrophic cancellation. This occurs when the data are nearly identical. Results may be unreliable.
#   results[i] = self.func(v, *self.args, **self.kwargs)
# Summary of correlations:
# ==================================================
# Top 10 highest correlations:
#  1. BLK_proton_density ↔ BLK_proton_bulk_speed: 1.000
#  2. BLK_proton_density ↔ BLK_proton_xvelocity: 1.000
#  3. BLK_proton_density ↔ BLK_proton_thermal: 1.000
#  4. BLK_proton_density ↔ BLK_alpha_bulk_speed: 1.000
#  5. BLK_proton_bulk_speed ↔ BLK_proton_xvelocity: 1.000
#  6. BLK_proton_bulk_speed ↔ BLK_proton_thermal: 1.000
#  7. BLK_proton_bulk_speed ↔ BLK_alpha_bulk_speed: 1.000
#  8. BLK_proton_xvelocity ↔ BLK_proton_thermal: 1.000
#  9. BLK_proton_xvelocity ↔ BLK_alpha_bulk_speed: 1.000
# 10. BLK_proton_thermal ↔ BLK_alpha_bulk_speed: 1.000
#
# Total number of variable pairs analyzed: 435
